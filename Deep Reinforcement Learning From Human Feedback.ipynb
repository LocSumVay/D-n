# %%
import tensorflow as tf
import numpy as np
import random
from tensorflow.keras import layers, models
from sklearn.utils import shuffle
from collections import deque
import pickle

loaded = np.load("arrays.npz")
x_train, x_test, y_train, y_test = loaded["array1"],loaded["array3"],loaded["array2"],loaded["array4"]
x_total = np.concatenate((x_train, x_test), axis=0)
y_total = np.concatenate((y_train, y_test), axis=0)
y_total.shape
# Out:
# (29940, 999)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Bidirectional ,GRU, Conv1D ,BatchNormalization,MaxPooling1D,Flatten
from tensorflow.keras.layers import Input, Conv1D, BatchNormalization, MaxPooling1D, Dropout, Flatten, Dense
from tensorflow.keras.models import Model

# Định nghĩa đầu vào
inputs = Input(shape=(20, 98))

# Lớp 1: Conv1D + BatchNorm + MaxPooling
x = Conv1D(64, kernel_size=3, activation='gelu', padding='same')(inputs)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.1)(x)

# Lớp 2: Conv1D + BatchNorm + MaxPooling
x = Conv1D(128, kernel_size=3, activation='gelu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.1)(x)

# Lớp 3: Conv1D + BatchNorm + MaxPooling
x = Conv1D(256, kernel_size=3, activation='gelu', padding='same')(x)
x = BatchNormalization()(x)
x = MaxPooling1D(pool_size=2)(x)
x = Dropout(0.1)(x)

# Lớp 4: Conv1D + BatchNorm
x = Conv1D(512, kernel_size=3, activation='gelu', padding='same')(x)
x = BatchNormalization()(x)
x = Dropout(0.1)(x)

# Flatten + Dense layers
x = Flatten()(x)
x = Dense(128, activation='gelu')(x)
x = Dropout(0.2)(x)

# Đầu ra
output = Dense(999, activation='sigmoid')(x)
# Tạo mô hình
model_sl= Model(inputs=inputs, outputs=output)

model_sl.compile(loss =tf.keras.losses.BinaryCrossentropy(), optimizer='adam', metrics=['accuracy',tf.keras.metrics.TopKCategoricalAccuracy(k=10)])
model_sl.summary()
History = model_sl.fit(x_train,y_train,validation_data=(x_total, y_total), epochs=100,batch_size=32)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 20, 98)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d (Conv1D)                      │ (None, 20, 64)              │          18,880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 20, 64)              │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d (MaxPooling1D)         │ (None, 10, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 10, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_1 (Conv1D)                    │ (None, 10, 128)             │          24,704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 10, 128)             │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_1 (MaxPooling1D)       │ (None, 5, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 5, 128)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_2 (Conv1D)                    │ (None, 5, 256)              │          98,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 5, 256)              │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling1d_2 (MaxPooling1D)       │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 2, 256)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv1d_3 (Conv1D)                    │ (None, 2, 512)              │         393,728 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 2, 512)              │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 2, 512)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         131,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 999)                 │         128,871 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 799,783 (3.05 MB)
#  Trainable params: 797,863 (3.04 MB)
#  Non-trainable params: 1,920 (7.50 KB)
# Epoch 1/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 11s 40ms/step - accuracy: 8.0452e-05 - loss: 0.1172 - top_k_categorical_accuracy: 0.0079 - val_accuracy: 0.0010 - val_loss: 0.0087 - val_top_k_categorical_accuracy: 0.0099
# Epoch 2/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 35ms/step - accuracy: 2.4858e-04 - loss: 0.0088 - top_k_categorical_accuracy: 0.0084 - val_accuracy: 9.3520e-04 - val_loss: 0.0082 - val_top_k_categorical_accuracy: 0.0106
# Epoch 3/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.0011 - loss: 0.0086 - top_k_categorical_accuracy: 0.0108 - val_accuracy: 0.0015 - val_loss: 0.0081 - val_top_k_categorical_accuracy: 0.0113
# Epoch 4/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 6.7150e-04 - loss: 0.0085 - top_k_categorical_accuracy: 0.0117 - val_accuracy: 0.0019 - val_loss: 0.0081 - val_top_k_categorical_accuracy: 0.0144
# Epoch 5/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.0013 - loss: 0.0084 - top_k_categorical_accuracy: 0.0140 - val_accuracy: 0.0022 - val_loss: 0.0080 - val_top_k_categorical_accuracy: 0.0243
# Epoch 6/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - accuracy: 0.0025 - loss: 0.0082 - top_k_categorical_accuracy: 0.0237 - val_accuracy: 0.0053 - val_loss: 0.0079 - val_top_k_categorical_accuracy: 0.0332
# Epoch 7/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.0036 - loss: 0.0078 - top_k_categorical_accuracy: 0.0525 - val_accuracy: 0.0088 - val_loss: 0.0074 - val_top_k_categorical_accuracy: 0.0720
# Epoch 8/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.0136 - loss: 0.0074 - top_k_categorical_accuracy: 0.0893 - val_accuracy: 0.0248 - val_loss: 0.0071 - val_top_k_categorical_accuracy: 0.1238
# Epoch 9/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.0215 - loss: 0.0069 - top_k_categorical_accuracy: 0.1366 - val_accuracy: 0.0421 - val_loss: 0.0065 - val_top_k_categorical_accuracy: 0.2143
# Epoch 10/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.0361 - loss: 0.0065 - top_k_categorical_accuracy: 0.2109 - val_accuracy: 0.0668 - val_loss: 0.0060 - val_top_k_categorical_accuracy: 0.3098
# Epoch 11/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.0679 - loss: 0.0060 - top_k_categorical_accuracy: 0.3071 - val_accuracy: 0.1029 - val_loss: 0.0056 - val_top_k_categorical_accuracy: 0.4072
# Epoch 12/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.0925 - loss: 0.0056 - top_k_categorical_accuracy: 0.4217 - val_accuracy: 0.1337 - val_loss: 0.0053 - val_top_k_categorical_accuracy: 0.4969
# Epoch 13/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.1410 - loss: 0.0052 - top_k_categorical_accuracy: 0.5142 - val_accuracy: 0.2003 - val_loss: 0.0047 - val_top_k_categorical_accuracy: 0.6055
# Epoch 14/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.1833 - loss: 0.0048 - top_k_categorical_accuracy: 0.5938 - val_accuracy: 0.2406 - val_loss: 0.0045 - val_top_k_categorical_accuracy: 0.6565
# Epoch 15/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.2375 - loss: 0.0044 - top_k_categorical_accuracy: 0.6764 - val_accuracy: 0.2914 - val_loss: 0.0041 - val_top_k_categorical_accuracy: 0.7239
# Epoch 16/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.2923 - loss: 0.0041 - top_k_categorical_accuracy: 0.7518 - val_accuracy: 0.3566 - val_loss: 0.0038 - val_top_k_categorical_accuracy: 0.7765
# Epoch 17/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.3328 - loss: 0.0038 - top_k_categorical_accuracy: 0.8053 - val_accuracy: 0.3799 - val_loss: 0.0036 - val_top_k_categorical_accuracy: 0.8086
# Epoch 18/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.3793 - loss: 0.0035 - top_k_categorical_accuracy: 0.8444 - val_accuracy: 0.3906 - val_loss: 0.0036 - val_top_k_categorical_accuracy: 0.8141
# Epoch 19/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.4207 - loss: 0.0033 - top_k_categorical_accuracy: 0.8811 - val_accuracy: 0.4502 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.8486
# Epoch 20/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.4696 - loss: 0.0031 - top_k_categorical_accuracy: 0.8971 - val_accuracy: 0.4954 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.8702
# Epoch 21/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.5202 - loss: 0.0028 - top_k_categorical_accuracy: 0.9314 - val_accuracy: 0.5189 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.8774
# Epoch 22/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.5602 - loss: 0.0027 - top_k_categorical_accuracy: 0.9445 - val_accuracy: 0.5396 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.8834
# Epoch 23/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.5892 - loss: 0.0025 - top_k_categorical_accuracy: 0.9669 - val_accuracy: 0.5662 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.8966
# Epoch 24/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.6344 - loss: 0.0023 - top_k_categorical_accuracy: 0.9659 - val_accuracy: 0.5712 - val_loss: 0.0027 - val_top_k_categorical_accuracy: 0.8990
# Epoch 25/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.6518 - loss: 0.0022 - top_k_categorical_accuracy: 0.9688 - val_accuracy: 0.5901 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9054
# Epoch 26/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.6841 - loss: 0.0021 - top_k_categorical_accuracy: 0.9759 - val_accuracy: 0.5867 - val_loss: 0.0027 - val_top_k_categorical_accuracy: 0.8995
# Epoch 27/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.6854 - loss: 0.0020 - top_k_categorical_accuracy: 0.9829 - val_accuracy: 0.6196 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9149
# Epoch 28/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.7287 - loss: 0.0019 - top_k_categorical_accuracy: 0.9844 - val_accuracy: 0.6289 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9164
# Epoch 29/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.7244 - loss: 0.0018 - top_k_categorical_accuracy: 0.9863 - val_accuracy: 0.6263 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9152
# Epoch 30/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.7406 - loss: 0.0018 - top_k_categorical_accuracy: 0.9877 - val_accuracy: 0.6301 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9151
# Epoch 31/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.7660 - loss: 0.0017 - top_k_categorical_accuracy: 0.9906 - val_accuracy: 0.6445 - val_loss: 0.0024 - val_top_k_categorical_accuracy: 0.9207
# Epoch 32/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.7831 - loss: 0.0016 - top_k_categorical_accuracy: 0.9891 - val_accuracy: 0.6472 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9188
# Epoch 33/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.8031 - loss: 0.0015 - top_k_categorical_accuracy: 0.9936 - val_accuracy: 0.6402 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9174
# Epoch 34/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.7976 - loss: 0.0014 - top_k_categorical_accuracy: 0.9947 - val_accuracy: 0.6572 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9206
# Epoch 35/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.8335 - loss: 0.0013 - top_k_categorical_accuracy: 0.9934 - val_accuracy: 0.6609 - val_loss: 0.0024 - val_top_k_categorical_accuracy: 0.9245
# Epoch 36/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8336 - loss: 0.0013 - top_k_categorical_accuracy: 0.9975 - val_accuracy: 0.6620 - val_loss: 0.0024 - val_top_k_categorical_accuracy: 0.9211
# Epoch 37/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8385 - loss: 0.0013 - top_k_categorical_accuracy: 0.9963 - val_accuracy: 0.6686 - val_loss: 0.0024 - val_top_k_categorical_accuracy: 0.9271
# Epoch 38/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8462 - loss: 0.0013 - top_k_categorical_accuracy: 0.9972 - val_accuracy: 0.6725 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9240
# Epoch 39/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.8476 - loss: 0.0012 - top_k_categorical_accuracy: 0.9973 - val_accuracy: 0.6674 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9216
# Epoch 40/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8629 - loss: 0.0011 - top_k_categorical_accuracy: 0.9973 - val_accuracy: 0.6693 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9233
# Epoch 41/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8444 - loss: 0.0012 - top_k_categorical_accuracy: 0.9951 - val_accuracy: 0.6661 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9195
# Epoch 42/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.8711 - loss: 0.0011 - top_k_categorical_accuracy: 0.9978 - val_accuracy: 0.6788 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9273
# Epoch 43/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8778 - loss: 0.0011 - top_k_categorical_accuracy: 0.9959 - val_accuracy: 0.6761 - val_loss: 0.0025 - val_top_k_categorical_accuracy: 0.9255
# Epoch 44/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.8893 - loss: 0.0010 - top_k_categorical_accuracy: 0.9987 - val_accuracy: 0.6798 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9249
# Epoch 45/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.8856 - loss: 0.0010 - top_k_categorical_accuracy: 0.9987 - val_accuracy: 0.6772 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9252
# Epoch 46/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.8907 - loss: 0.0010 - top_k_categorical_accuracy: 0.9974 - val_accuracy: 0.6790 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9275
# Epoch 47/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.8892 - loss: 9.8210e-04 - top_k_categorical_accuracy: 0.9989 - val_accuracy: 0.6839 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9255
# Epoch 48/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8793 - loss: 0.0010 - top_k_categorical_accuracy: 0.9992 - val_accuracy: 0.6863 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9260
# Epoch 49/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9003 - loss: 9.3999e-04 - top_k_categorical_accuracy: 0.9977 - val_accuracy: 0.6832 - val_loss: 0.0026 - val_top_k_categorical_accuracy: 0.9267
# Epoch 50/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.8904 - loss: 9.7474e-04 - top_k_categorical_accuracy: 0.9990 - val_accuracy: 0.6826 - val_loss: 0.0027 - val_top_k_categorical_accuracy: 0.9262
# Epoch 51/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9118 - loss: 8.5280e-04 - top_k_categorical_accuracy: 0.9993 - val_accuracy: 0.6773 - val_loss: 0.0027 - val_top_k_categorical_accuracy: 0.9230
# Epoch 52/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9092 - loss: 8.7274e-04 - top_k_categorical_accuracy: 0.9991 - val_accuracy: 0.6827 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.9252
# Epoch 53/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9161 - loss: 8.8259e-04 - top_k_categorical_accuracy: 0.9986 - val_accuracy: 0.6887 - val_loss: 0.0027 - val_top_k_categorical_accuracy: 0.9291
# Epoch 54/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.8974 - loss: 0.0010 - top_k_categorical_accuracy: 0.9984 - val_accuracy: 0.6794 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.9244
# Epoch 55/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9143 - loss: 9.0025e-04 - top_k_categorical_accuracy: 0.9980 - val_accuracy: 0.6855 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.9227
# Epoch 56/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9203 - loss: 7.9834e-04 - top_k_categorical_accuracy: 0.9991 - val_accuracy: 0.6867 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.9259
# Epoch 57/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9031 - loss: 8.5463e-04 - top_k_categorical_accuracy: 0.9984 - val_accuracy: 0.6843 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.9224
# Epoch 58/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9252 - loss: 8.1202e-04 - top_k_categorical_accuracy: 0.9992 - val_accuracy: 0.6879 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.9269
# Epoch 59/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9336 - loss: 7.3360e-04 - top_k_categorical_accuracy: 0.9989 - val_accuracy: 0.6880 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.9239
# Epoch 60/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9239 - loss: 7.8788e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6894 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.9259
# Epoch 61/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9263 - loss: 7.5590e-04 - top_k_categorical_accuracy: 0.9995 - val_accuracy: 0.6886 - val_loss: 0.0028 - val_top_k_categorical_accuracy: 0.9258
# Epoch 62/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9291 - loss: 7.9091e-04 - top_k_categorical_accuracy: 0.9995 - val_accuracy: 0.6878 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.9230
# Epoch 63/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.9340 - loss: 7.0646e-04 - top_k_categorical_accuracy: 0.9997 - val_accuracy: 0.6854 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.9222
# Epoch 64/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9293 - loss: 6.9110e-04 - top_k_categorical_accuracy: 0.9993 - val_accuracy: 0.6863 - val_loss: 0.0030 - val_top_k_categorical_accuracy: 0.9255
# Epoch 65/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9342 - loss: 7.2515e-04 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.6917 - val_loss: 0.0029 - val_top_k_categorical_accuracy: 0.9240
# Epoch 66/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9279 - loss: 7.5113e-04 - top_k_categorical_accuracy: 0.9988 - val_accuracy: 0.6846 - val_loss: 0.0030 - val_top_k_categorical_accuracy: 0.9237
# Epoch 67/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9180 - loss: 8.2184e-04 - top_k_categorical_accuracy: 0.9974 - val_accuracy: 0.6865 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9212
# Epoch 68/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9349 - loss: 7.2867e-04 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.6928 - val_loss: 0.0030 - val_top_k_categorical_accuracy: 0.9243
# Epoch 69/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9393 - loss: 7.1707e-04 - top_k_categorical_accuracy: 0.9987 - val_accuracy: 0.6909 - val_loss: 0.0030 - val_top_k_categorical_accuracy: 0.9277
# Epoch 70/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.9406 - loss: 6.9154e-04 - top_k_categorical_accuracy: 0.9994 - val_accuracy: 0.6886 - val_loss: 0.0030 - val_top_k_categorical_accuracy: 0.9275
# Epoch 71/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9333 - loss: 7.0371e-04 - top_k_categorical_accuracy: 0.9992 - val_accuracy: 0.6922 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9252
# Epoch 72/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9432 - loss: 6.6624e-04 - top_k_categorical_accuracy: 0.9991 - val_accuracy: 0.6896 - val_loss: 0.0030 - val_top_k_categorical_accuracy: 0.9243
# Epoch 73/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9456 - loss: 6.5340e-04 - top_k_categorical_accuracy: 0.9987 - val_accuracy: 0.6882 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9244
# Epoch 74/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9498 - loss: 6.0718e-04 - top_k_categorical_accuracy: 0.9997 - val_accuracy: 0.6906 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9235
# Epoch 75/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9531 - loss: 5.8827e-04 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.6886 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9217
# Epoch 76/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9395 - loss: 6.7872e-04 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.6929 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9248
# Epoch 77/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9432 - loss: 6.4401e-04 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.6923 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9249
# Epoch 78/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9439 - loss: 6.4651e-04 - top_k_categorical_accuracy: 0.9987 - val_accuracy: 0.6987 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9260
# Epoch 79/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9515 - loss: 6.2316e-04 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.6934 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9266
# Epoch 80/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9507 - loss: 6.2918e-04 - top_k_categorical_accuracy: 0.9997 - val_accuracy: 0.6926 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9231
# Epoch 81/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9522 - loss: 5.9335e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6974 - val_loss: 0.0031 - val_top_k_categorical_accuracy: 0.9273
# Epoch 82/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9575 - loss: 5.3461e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6984 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9273
# Epoch 83/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - accuracy: 0.9482 - loss: 5.8335e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6947 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9259
# Epoch 84/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9485 - loss: 5.8965e-04 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.6927 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9227
# Epoch 85/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9595 - loss: 5.6184e-04 - top_k_categorical_accuracy: 0.9997 - val_accuracy: 0.6922 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.9244
# Epoch 86/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9590 - loss: 5.4425e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6919 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.9236
# Epoch 87/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - accuracy: 0.9535 - loss: 5.7046e-04 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.6960 - val_loss: 0.0032 - val_top_k_categorical_accuracy: 0.9240
# Epoch 88/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9598 - loss: 5.1475e-04 - top_k_categorical_accuracy: 0.9995 - val_accuracy: 0.6931 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.9252
# Epoch 89/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9387 - loss: 6.8738e-04 - top_k_categorical_accuracy: 0.9996 - val_accuracy: 0.6899 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.9238
# Epoch 90/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - accuracy: 0.9515 - loss: 5.9076e-04 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.6921 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9250
# Epoch 91/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 49ms/step - accuracy: 0.9542 - loss: 5.7543e-04 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.7004 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.9270
# Epoch 92/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 48ms/step - accuracy: 0.9665 - loss: 5.1193e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6978 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9257
# Epoch 93/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - accuracy: 0.9628 - loss: 4.7218e-04 - top_k_categorical_accuracy: 0.9998 - val_accuracy: 0.6962 - val_loss: 0.0033 - val_top_k_categorical_accuracy: 0.9257
# Epoch 94/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.9650 - loss: 5.5371e-04 - top_k_categorical_accuracy: 0.9982 - val_accuracy: 0.6946 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9246
# Epoch 95/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - accuracy: 0.9561 - loss: 5.5944e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6961 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9260
# Epoch 96/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.9611 - loss: 5.3644e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6932 - val_loss: 0.0035 - val_top_k_categorical_accuracy: 0.9264
# Epoch 97/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - accuracy: 0.9623 - loss: 5.1951e-04 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.6927 - val_loss: 0.0035 - val_top_k_categorical_accuracy: 0.9219
# Epoch 98/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 9s 47ms/step - accuracy: 0.9644 - loss: 4.7528e-04 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.6975 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9235
# Epoch 99/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 8s 45ms/step - accuracy: 0.9590 - loss: 5.0471e-04 - top_k_categorical_accuracy: 0.9999 - val_accuracy: 0.6959 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9229
# Epoch 100/100
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 10s 51ms/step - accuracy: 0.9650 - loss: 4.7117e-04 - top_k_categorical_accuracy: 1.0000 - val_accuracy: 0.6941 - val_loss: 0.0034 - val_top_k_categorical_accuracy: 0.9237

# %%
class Env:
    def __init__(self, x_data, y_data, num_classes):
        self.x_data, self.y_data = shuffle(x_data, y_data)  # Shuffle data
        self.num_classes = num_classes
        self.current_idx = 0
        self.remaining_indices = 999
    def reset(self):
        #lấy state Ngẫu nhiên đầy đủ
        self.current_idx += 1
        return self.x_data[self.current_idx]

   
    def step(self, action):
        action_ = np.argsort(action[0])[-10:][::-1]
        
        true_label = np.argmax(self.y_data[self.current_idx])
        # Nếu dự đoán đúng
        eward =[1 if int(word) == int(true_label) else 0 for word in action_]
        if int(true_label) in action_:
            reward = action[0]
            reward[action_] = 0
            reward[true_label] = 1
        else:
            reward = action[0]
            reward[action_] = 0
        max_value_index = np.argmax(action[0])
        acti = np.zeros(len(action[0]))
        acti[true_label] = 1
        return  acti,reward,eward

# %%
import tensorflow
def min_max_normalization(values):
    values = np.array(values)
    min_val = np.min(values)
    max_val = np.max(values)
    return (values - min_val) / (max_val - min_val)
def accuracy(y_true, y_pred):
    y_pred_labels = tf.argmax(y_pred, axis=1)
    y_true_labels = tf.argmax(y_true, axis=1)
    
    # So sánh và tính độ chính xác
    accuracy = tf.reduce_mean(tf.cast(y_pred_labels == y_true_labels, tf.float32))
    
    top_10_preds = np.argsort(y_pred, axis=1)[:, -10:]  
    matches = [y_true_labels[i] in top_10_preds[i] for i in range(len(y_true))]
    # Tính tỷ lệ chính xác top 1
    accuracy_ = np.mean(matches)
    #print(f'**********-------Accuracy:{accuracy}-------- Accuracy_Top_10:{Accuracy_}')
    return accuracy.numpy(),accuracy_
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv1D, Dense, GlobalMaxPooling1D, MultiHeadAttention, Dropout, Concatenate, Reshape, Flatten
from tensorflow.keras.models import Model

# Đầu vào 1: Chuỗi dữ liệu qua Conv1D
input1 = Input(shape=(20, 98), name="conv1d_input")  # (seq_len, feature_dim)
x = Conv1D(filters=64, kernel_size=3, activation="gelu")(input1)  # (batch_size, seq_len, filters)
x = Conv1D(filters=64, kernel_size=3, activation="gelu")(x) 
x = Flatten()(x)
#x = Reshape((1, 1024))(x)
# Đầu vào 2: Vector đặc trưng
input2 = Input(shape=(999,), name="vector_input")  # 
x2 = Dense(1024, activation="gelu")(input2)
output = Dense(999, activation="linear")(x*x2)  # Phân loại 10 lớp

# Xây dựng mô hình
model_reward = Model(inputs=[input1, input2], outputs=output)

# Compile mô hình
model_reward.compile(optimizer='adam', loss='mse', metrics=["accuracy"])

# Hiển thị kiến trúc
model_reward.summary()
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='accuracy',  # Theo dõi giá trị val_loss
    patience=3,          # Dừng nếu không cải thiện sau 5 epoch
    restore_best_weights=True  # Phục hồi trọng số tốt nhất
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ conv1d_input (InputLayer)     │ (None, 20, 98)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_4 (Conv1D)             │ (None, 18, 64)            │          18,880 │ conv1d_input[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_5 (Conv1D)             │ (None, 16, 64)            │          12,352 │ conv1d_4[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ vector_input (InputLayer)     │ (None, 999)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 1024)              │               0 │ conv1d_5[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 1024)              │       1,024,000 │ vector_input[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ multiply (Multiply)           │ (None, 1024)              │               0 │ flatten_1[0][0],           │
# │                               │                           │                 │ dense_2[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_3 (Dense)               │ (None, 999)               │       1,023,975 │ multiply[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,079,207 (7.93 MB)
#  Trainable params: 2,079,207 (7.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Lớp Replay Buffer

class ReplayBuffer:
    def __init__(self, capacity):

        self.capacity = capacity
        self.buffer = []
        self.position = 0

    def add(self, state, action, reward, probability):
        transition = (state, action, reward, probability)

        if len(self.buffer) < self.capacity:
            self.buffer.append(transition)
        else:
            self.buffer[self.position] = transition

        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        if batch_size > len(self.buffer):
            batch_size = len(self.buffer)
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, probabilities = zip(*batch)
        return (
            np.array(states),
            np.array(actions),
            np.array(rewards),
            np.array(probabilities),
        )
    def sample_r(self, n):
        recent = self.buffer[-n:] if n <= len(self.buffer) else self.buffer
        states, actions, rewards, probabilities = zip(*recent)
        return (
            np.array(states),
            np.array(actions),
            np.array(rewards),
            np.array(probabilities),
        )

    def __len__(self):
        return len(self.buffer)
    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self.buffer, f)

    def load(self, filename):
        with open(filename, 'rb') as f:
            self.buffer = pickle.load(f)
    def del_(self, n):
        """Xóa `n` phần tử đầu tiên trong buffer."""
        if n <= len(self.buffer):
            self.buffer = self.buffer[n:]
        else:
            self.buffer = []
    def save(self, filename):
        with open(filename, 'wb') as f:
            pickle.dump(self.buffer, f)

    def load(self, filename):
        with open(filename, 'rb') as f:
            self.buffer = pickle.load(f)
ReplayBuffer = ReplayBuffer(30000)

# %%
import tensorflow as tf
import numpy as np

# Hàm cập nhật PPO đơn giản
def update(model, ReplayBuffer, clip_ratio=0.3, learning_rate=3e-4, epochs=2, batch_size=32):
    # Khởi tạo optimizer
    def ewc_loss(y_true, y_pred, model, fisher_information, weights_before):
        # Mất mát cho tác vụ mới
        task_loss = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)

        # Tính phần phạt EWC
        ewc_penalty = 0
        for var, fisher, weight_old in zip(model.trainable_variables, fisher_information, weights_before):
            ewc_penalty += tf.reduce_sum(fisher * tf.square(var - weight_old))

        # Tổng hợp hàm mất mát
        return task_loss + lambda_ewc * ewc_penalty
    optimizer = tf.keras.optimizers.Adam()

    # Huấn luyện mô hình trên tác vụ mới
    def fit_ewc(model,x_train_new,y_train_new,epochss):
        stop1 = 0
        weights_before = model.trainable_variables
        for epoch in range(epochss):
            for x_batch, y_batch in tf.data.Dataset.from_tensor_slices((x_train_new, y_train_new)).batch(32):
                with tf.GradientTape() as tape:
                    logits = model(x_batch, training=True)
                    loss = ewc_loss(y_batch, logits, model, fisher_information, weights_before)
                # Cập nhật trọng số
                grads = tape.gradient(loss, model.trainable_variables)
                optimizer.apply_gradients(zip(grads, model.trainable_variables))
            predict = agent.model(x_train_new)
            b1,b2 = accuracy(y_train_new,predict)

            y_predict = agent.model(x_total)
            a1,a2 = accuracy(y_total,y_predict)
            print(f"Epoch {epoch + 1}: Loss = {loss.numpy().mean()}--------------- Accuracy : {a1}--- {a2}")
            if stop1/b1 > 0.98:
                break
            else:
                stop1 = b1
        y_predict = agent.model(x_total)
        a1,a2 = accuracy(y_total,y_predict)
        kq_1.append(a1)
        kq_2.append(a2)

    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
    # Lấy dữ liệu từ replay buffer
    states1, actions1 ,rewards1,probability1 = ReplayBuffer.sample_r(6000)
    rewards1 = min_max_normalization(rewards1)
    probability_ = min_max_normalization(probability1)
    states = tf.convert_to_tensor(states1, dtype=tf.float32)
    actions = tf.convert_to_tensor(actions1, dtype=tf.int32)
    rewards = tf.convert_to_tensor(rewards1, dtype=tf.float32)
    probability = tf.convert_to_tensor(probability1, dtype=tf.float32)
    model_reward.fit([states1,probability_],rewards1 , epochs=20,batch_size=32)

    rewa = model_reward.predict([states1,probability_])
    rewa = min_max_normalization(rewa**2)
    fit_ewc(model,states1, rewa,2)

    y_predict = agent.model(x_total)
    a3,a4 = accuracy(y_total,y_predict)
    kq_3.append(a3)
    kq_4.append(a4)
    print(f'Accuracy:{a3}********************{a4}')

# %%
class Agent:
    def __init__(self):
        self.state_shape = (20,98)
        self.action_space = 999
        self.batch_size = 32
        self.epsilon = 1.0
        self.epsilon_min = 0.99
        self.epsilon_decay = 0.995
        self.gamma = 0.95
        self.model = model_sl
        
        #self.replay_buffer = ReplayBuffer(30000)
        
    def act(self, state):

        q_values = self.model.predict(state, verbose=0)
        return q_values
    def key(self):
        tokenizer = pickle.load(open('tokenizer.pkl', 'rb'))
        word_index = tokenizer.word_index
        key = list(word_index.keys())
        return key
        
    def remember(self, state, action, reward):
        self.replay_buffer.add((state, action, reward ,probability))
        
    
    def update_target_model(self,Replaybuffer):
        update(self.model, Replaybuffer)
        # Cập nhật target model sau mỗi 1000 episode

# %%
fisher_information = []
#state_, action_, reward_, probability_
# Duyệt qua tập dữ liệu để tính toán Fisher Information
for x, y in tf.data.Dataset.from_tensor_slices((x_train,y_train)).batch(32):
    with tf.GradientTape() as tape:
        # Kích hoạt gradient theo các trọng số mô hình
        logits = model_sl(x, training=False)
        loss = tf.keras.losses.BinaryCrossentropy()(y, logits)
    # Tính gradient của loss đối với tất cả trọng số
    grads = tape.gradient(loss, model_sl.trainable_variables)

    # Bình phương gradient và cộng dồn
    if not fisher_information:
        fisher_information = [tf.square(g) for g in grads]
    else:
        fisher_information = [f + tf.square(g) for f, g in zip(fisher_information, grads)]

# Lấy giá trị trung bình Fisher Information trên toàn bộ dữ liệu
fisher_information = [f / len(x_train) for f in fisher_information]


# Hệ số điều chỉnh λ

lambda_ewc = 0.1

# %%
agent = Agent()
batch_size = 32
episodes =5900
evn = Env(x_train,y_train,999)

kq = []
# Huấn luyện agent
kq_1 = []
kq_2 = []
kq_3 = []
kq_4 = []
n = 2
for e in range(episodes):
    state = evn.reset()
    state = np.expand_dims(state, axis=0)  # Thêm chiều batch
    probability = agent.act(state)
  
    action,reward,uu = evn.step(probability)
    kq.append(uu)
    ReplayBuffer.add(state[0], action, reward, probability[0])
    
        
    e += 1

# %%
rw  = []
agent = Agent()
memory = deque(maxlen=10000)
batch_size = 32
episodes =24000
#evn = Env(x_train,y_train,999)
evn = Env(x_test,y_test,999)
kq = []
los = []
# Huấn luyện agent
kq_1 = []
kq_2 = []
kq_3 = []
kq_4 = []
n = 2
for e in range(episodes):
    state = evn.reset()
    state = np.expand_dims(state, axis=0)  # Thêm chiều batch
    probability = agent.act(state)
  
    action,reward,uu = evn.step(probability)
    kq.append(uu)
    ReplayBuffer.add(state[0], action, reward, probability[0])
    
        
    e += 1

    if e % 1000 == 0:
        agent.update_target_model(ReplayBuffer)
        print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')



        # Cập nhật target model sau mỗi episode
        #if episodes // 30 ==0:
           # agent.update_target_model(
# Out:
# Epoch 1/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 9.6371e-04 - loss: 0.0142
# Epoch 2/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0017 - loss: 9.8747e-04
# Epoch 3/3
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.0022 - loss: 9.8524e-04
# 188/188 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Epoch 1: Loss = 0.08732977509498596--------------- Accuracy : 0.3807949125766754--- 0.7004008016032064
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 29
#      26 e += 1
#      28 if e % 1000 == 0:
# ---> 29     agent.update_target_model(ReplayBuffer)
#      30     print('%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%')
#      34     # Cập nhật target model sau mỗi episode
#      35     #if episodes // 30 ==0:
#      36        # agent.update_target_model(
#
# Cell In[7], line 29, in Agent.update_target_model(self, Replaybuffer)
#      28 def update_target_model(self,Replaybuffer):
# ---> 29     update(self.model, Replaybuffer)
#
# Cell In[6], line 60, in update(model, ReplayBuffer, clip_ratio, learning_rate, epochs, batch_size)
#      58 rewa = model_reward.predict([states1,probability_])
#      59 rewa = min_max_normalization(rewa**2)
# ---> 60 fit_ewc(model,states1, rewa,2)
#      62 y_predict = agent.model(x_total)
#      63 a3,a4 = accuracy(y_total,y_predict)
#
# Cell In[6], line 31, in update.<locals>.fit_ewc(model, x_train_new, y_train_new, epochss)
#      29     # Cập nhật trọng số
#      30     grads = tape.gradient(loss, model.trainable_variables)
# ---> 31     optimizer.apply_gradients(zip(grads, model.trainable_variables))
#      32 predict = agent.model(x_train_new)
#      33 b1,b2 = accuracy(y_train_new,predict)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\base_optimizer.py:291, in BaseOptimizer.apply_gradients(self, grads_and_vars)
#     289 def apply_gradients(self, grads_and_vars):
#     290     grads, trainable_variables = zip(*grads_and_vars)
# --> 291     self.apply(grads, trainable_variables)
#     292     # Return iterations for compat with tf.keras.
#     293     return self._iterations
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\base_optimizer.py:356, in BaseOptimizer.apply(self, grads, trainable_variables)
#     353     grads = [g if g is None else g / scale for g in grads]
#     355 # Apply gradient updates.
# --> 356 self._backend_apply_gradients(grads, trainable_variables)
#     357 # Apply variable constraints after applying gradients.
#     358 for variable in trainable_variables:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\base_optimizer.py:419, in BaseOptimizer._backend_apply_gradients(self, grads, trainable_variables)
#     416     self._apply_weight_decay(trainable_variables)
#     418     # Run udpate step.
# --> 419     self._backend_update_step(
#     420         grads, trainable_variables, self.learning_rate
#     421     )
#     423 if self.use_ema:
#     424     self._update_model_variables_moving_average(
#     425         self._trainable_variables
#     426     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:121, in TFOptimizer._backend_update_step(self, grads, trainable_variables, learning_rate)
#     119 grads_and_vars = list(zip(grads, trainable_variables))
#     120 grads_and_vars = self._all_reduce_sum_gradients(grads_and_vars)
# --> 121 tf.__internal__.distribute.interim.maybe_merge_call(
#     122     self._distributed_tf_update_step,
#     123     self._distribution_strategy,
#     124     grads_and_vars,
#     125     learning_rate,
#     126 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\merge_call_interim.py:51, in maybe_merge_call(fn, strategy, *args, **kwargs)
#      31 """Maybe invoke `fn` via `merge_call` which may or may not be fulfilled.
#      32
#      33 The caller of this utility function requests to invoke `fn` via `merge_call`
#    (...)
#      48   The return value of the `fn` call.
#      49 """
#      50 if strategy_supports_no_merge_call():
# ---> 51   return fn(strategy, *args, **kwargs)
#      52 else:
#      53   return distribute_lib.get_replica_context().merge_call(
#      54       fn, args=args, kwargs=kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:135, in TFOptimizer._distributed_tf_update_step(self, distribution, grads_and_vars, learning_rate)
#     132     return self.update_step(grad, var, learning_rate)
#     134 for grad, var in grads_and_vars:
# --> 135     distribution.extended.update(
#     136         var,
#     137         apply_grad_to_update_var,
#     138         args=(grad, learning_rate),
#     139         group=False,
#     140     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:3005, in StrategyExtendedV2.update(self, var, fn, args, kwargs, group)
#    3002   fn = autograph.tf_convert(
#    3003       fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
#    3004   with self._container_strategy().scope():
# -> 3005     return self._update(var, fn, args, kwargs, group)
#    3006 else:
#    3007   return self._replica_ctx_update(
#    3008       var, fn, args=args, kwargs=kwargs, group=group)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4075, in _DefaultDistributionExtended._update(self, var, fn, args, kwargs, group)
#    4072 def _update(self, var, fn, args, kwargs, group):
#    4073   # The implementations of _update() and _update_non_slot() are identical
#    4074   # except _update() passes `var` as the first argument to `fn()`.
# -> 4075   return self._update_non_slot(var, fn, (var,) + tuple(args), kwargs, group)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:4081, in _DefaultDistributionExtended._update_non_slot(self, colocate_with, fn, args, kwargs, should_group)
#    4077 def _update_non_slot(self, colocate_with, fn, args, kwargs, should_group):
#    4078   # TODO(josh11b): Figure out what we should be passing to UpdateContext()
#    4079   # once that value is used for something.
#    4080   with UpdateContext(colocate_with):
# -> 4081     result = fn(*args, **kwargs)
#    4082     if should_group:
#    4083       return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\autograph\impl\api.py:596, in call_with_unspecified_conversion_status.<locals>.wrapper(*args, **kwargs)
#     594 def wrapper(*args, **kwargs):
#     595   with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.UNSPECIFIED):
# --> 596     return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\optimizer.py:132, in TFOptimizer._distributed_tf_update_step.<locals>.apply_grad_to_update_var(var, grad, learning_rate)
#     131 def apply_grad_to_update_var(var, grad, learning_rate):
# --> 132     return self.update_step(grad, var, learning_rate)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\adam.py:119, in Adam.update_step(self, gradient, variable, learning_rate)
#     117 lr = ops.cast(learning_rate, variable.dtype)
#     118 gradient = ops.cast(gradient, variable.dtype)
# --> 119 local_step = ops.cast(self.iterations + 1, variable.dtype)
#     120 beta_1_power = ops.power(
#     121     ops.cast(self.beta_1, variable.dtype), local_step
#     122 )
#     123 beta_2_power = ops.power(
#     124     ops.cast(self.beta_2, variable.dtype), local_step
#     125 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\common\variables.py:404, in KerasVariable.__add__(self, other)
#     403 def __add__(self, other):
# --> 404     return backend.numpy.add(self.value, other)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\sparse.py:493, in elementwise_binary_union.<locals>.wrap_elementwise_binary_union.<locals>.sparse_wrapper(x1, x2)
#     490 elif isinstance(x2, tf.IndexedSlices):
#     491     # x2 is an IndexedSlices, densify.
#     492     x2 = tf.convert_to_tensor(x2)
# --> 493 return func(x1, x2)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend\tensorflow\numpy.py:38, in add(x1, x2)
#      36 x1 = convert_to_tensor(x1, dtype)
#      37 x2 = convert_to_tensor(x2, dtype)
# ---> 38 return tf.add(x1, x2)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\weak_tensor_ops.py:142, in weak_tensor_binary_op_wrapper.<locals>.wrapper(*args, **kwargs)
#     140 def wrapper(*args, **kwargs):
#     141   if not ops.is_auto_dtype_conversion_enabled():
# --> 142     return op(*args, **kwargs)
#     143   bound_arguments = signature.bind(*args, **kwargs)
#     144   bound_arguments.apply_defaults()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\util\dispatch.py:1260, in add_dispatch_support.<locals>.decorator.<locals>.op_dispatch_handler(*args, **kwargs)
#    1258 # Fallback dispatch system (dispatch v1):
#    1259 try:
# -> 1260   return dispatch_target(*args, **kwargs)
#    1261 except (TypeError, ValueError):
#    1262   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1263   # TypeError, when given unexpected types.  So we need to catch both.
#    1264   result = dispatch(op_dispatch_handler, args, kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\math_ops.py:3914, in add(x, y, name)
#    3845 """Returns x + y element-wise.
#    3846
#    3847 Example usages below.
#    (...)
#    3911   name: A name for the operation (optional)
#    3912 """
#    3913 with ops.name_scope(name, "Add", [x]) as name:
# -> 3914   x = ops.convert_to_tensor(x, name="x")
#    3915   y = ops.convert_to_tensor(y, dtype_hint=x.dtype.base_dtype, name="y")
#    3916   if x.dtype == dtypes.string:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\profiler\trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\ops.py:713, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#     711 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#     712 preferred_dtype = preferred_dtype or dtype_hint
# --> 713 return tensor_conversion_registry.convert(
#     714     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#     715 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:2375, in _dense_var_to_tensor(var, dtype, name, as_ref)
#    2374 def _dense_var_to_tensor(var, dtype=None, name=None, as_ref=False):
# -> 2375   return var._dense_var_to_tensor(dtype=dtype, name=name, as_ref=as_ref)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:1621, in BaseResourceVariable._dense_var_to_tensor(***failed resolving arguments***)
#    1619   return self.read_value().op.inputs[0]
#    1620 else:
# -> 1621   return self.value()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:656, in BaseResourceVariable.value(self)
#     654   return self._cached_value
#     655 with ops.colocate_with(None, ignore_existing=True):
# --> 656   return self._read_variable_op()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:841, in BaseResourceVariable._read_variable_op(self, no_copy)
#     839       result = read_and_set_handle(no_copy)
#     840 else:
# --> 841   result = read_and_set_handle(no_copy)
#     843 if not context.executing_eagerly():
#     844   # Note that if a control flow context is active the input of the read op
#     845   # might not actually be the handle. This line bypasses it.
#     846   record.record_operation(
#     847       "ReadVariableOp", [result], [self.handle],
#     848       backward_function=lambda x: [x],
#     849       forward_function=lambda x: [x])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:831, in BaseResourceVariable._read_variable_op.<locals>.read_and_set_handle(no_copy)
#     829 if no_copy and forward_compat.forward_compatible(2022, 5, 3):
#     830   gen_resource_variable_ops.disable_copy_on_read(self.handle)
# --> 831 result = gen_resource_variable_ops.read_variable_op(
#     832     self.handle, self._dtype)
#     833 _maybe_set_handle_data(self._dtype, self.handle, result)
#     834 return result
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py:590, in read_variable_op(resource, dtype, name)
#     588 if tld.is_eager:
#     589   try:
# --> 590     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     591       _ctx, "ReadVariableOp", name, resource, "dtype", dtype)
#     592     return _result
#     593   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
